# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import glob

# %%
pwd
# Out:
# '/Users/user/Desktop/2023python/StatModels'

# %%
df = pd.read_csv("datasets/churn_train.csv")
df
# Out:
#      state  account_length      area_code international_plan voice_mail_plan  \
# 0       OH             107  area_code_415                 no             yes
# 1       NJ             137  area_code_415                 no              no
# 2       OH              84  area_code_408                yes              no
# 3       OK              75  area_code_415                yes              no
# 4       MA             121  area_code_510                 no             yes
# ...    ...             ...            ...                ...             ...
# 4245    MT              83  area_code_415                 no              no
# 4246    WV              73  area_code_408                 no              no
# 4247    NC              75  area_code_408                 no              no
# 4248    HI              50  area_code_408                 no             yes
# 4249    VT              86  area_code_415                 no             yes
#
# ...

# %%
df = pd.read_csv("datasets/internet_service_churn.csv")
df
# Out:
#             id  is_tv_subscriber  is_movie_package_subscriber  \
# 0           15                 1                            0
# 1           18                 0                            0
# 2           23                 1                            0
# 3           27                 0                            0
# 4           34                 0                            0
# ...        ...               ...                          ...
# 72269  1689648                 1                            1
# 72270  1689676                 1                            0
# 72271  1689679                 1                            0
# 72272  1689733                 0                            0
# 72273  1689744                 1                            1
#
#        subscription_age  bill_avg  reamining_contract  service_failure_count  \
# 0                 11.95        25                0.14                      0
# ...

# %%
df = pd.read_csv("datasets/telecom_customer_churn.csv")
df
# Out:
#      Customer ID  Gender  Age Married  Number of Dependents          City  \
# 0     0002-ORFBO  Female   37     Yes                     0  Frazier Park
# 1     0003-MKNFE    Male   46      No                     0      Glendale
# 2     0004-TLHLJ    Male   50      No                     0    Costa Mesa
# 3     0011-IGKFF    Male   78     Yes                     0      Martinez
# 4     0013-EXCHZ  Female   75     Yes                     0     Camarillo
# ...          ...     ...  ...     ...                   ...           ...
# 7038  9987-LUTYD  Female   20      No                     0       La Mesa
# 7039  9992-RRAMN    Male   40     Yes                     0     Riverbank
# 7040  9992-UJOEL    Male   22      No                     0           Elk
# 7041  9993-LHIEB    Male   21     Yes                     0  Solana Beach
# 7042  9995-HOTOH    Male   36     Yes                     0   Sierra City
#
#       Zip Code   Latitude   Longitude  Number of Referrals  ...  \
# ...

# %%
df = pd.read_csv("datasets/KAG_conversion_data.csv")
df
# Out:
#         ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 0      708746              916          103916  30-34      M        15
# 1      708749              916          103917  30-34      M        16
# 2      708771              916          103920  30-34      M        20
# 3      708815              916          103928  30-34      M        28
# 4      708818              916          103928  30-34      M        28
# ...       ...              ...             ...    ...    ...       ...
# 1138  1314410             1178          179977  45-49      F       109
# 1139  1314411             1178          179978  45-49      F       110
# 1140  1314412             1178          179979  45-49      F       111
# 1141  1314414             1178          179981  45-49      F       113
# 1142  1314415             1178          179982  45-49      F       114
#
#       Impressions  Clicks       Spent  Total_Conversion  Approved_Conversion
# ...

# %%
df = pd.read_csv("datasets/Churn_Modelling.csv")
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

# %%
df.select_dtypes(include=numerics)
# Out:
#       RowNumber  CustomerId  CreditScore  Age  Tenure    Balance  \
# 0             1    15634602          619   42       2       0.00
# 1             2    15647311          608   41       1   83807.86
# 2             3    15619304          502   42       8  159660.80
# 3             4    15701354          699   39       1       0.00
# 4             5    15737888          850   43       2  125510.82
# ...         ...         ...          ...  ...     ...        ...
# 9995       9996    15606229          771   39       5       0.00
# 9996       9997    15569892          516   35      10   57369.61
# 9997       9998    15584532          709   36       7       0.00
# 9998       9999    15682355          772   42       3   75075.31
# 9999      10000    15628319          792   28       4  130142.79
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0                 1          1               1        101348.88       1
# ...

# %%
df_numeric= df.select_dtypes(include=numerics)

# %%
df_numeric.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'CreditScore', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Exited'],
#       dtype='object')

# %%
df_numeric = df_numeric[['CreditScore', 'Age', 'Tenure', 'Balance',
       'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
       'Exited']]

# %%
df_numeric .shape
# Out:
# (10000, 9)

# %%
df_numeric.describe().T
# Out:
#                    count           mean           std     min       25%  \
# CreditScore      10000.0     650.528800     96.653299  350.00    584.00
# Age              10000.0      38.921800     10.487806   18.00     32.00
# Tenure           10000.0       5.012800      2.892174    0.00      3.00
# Balance          10000.0   76485.889288  62397.405202    0.00      0.00
# NumOfProducts    10000.0       1.530200      0.581654    1.00      1.00
# HasCrCard        10000.0       0.705500      0.455840    0.00      0.00
# IsActiveMember   10000.0       0.515100      0.499797    0.00      0.00
# EstimatedSalary  10000.0  100090.239881  57510.492818   11.58  51002.11
# Exited           10000.0       0.203700      0.402769    0.00      0.00
#
#                         50%          75%        max
# CreditScore         652.000     718.0000     850.00
# Age                  37.000      44.0000      92.00
# Tenure                5.000       7.0000      10.00
# ...

# %%
import statsmodels.api as sm

# %%
import sklearn
from sklearn.preprocessing import StandardScaler

# %%
Xtrain = df_numeric[['CreditScore', 'Age', 'Tenure', 'Balance',
       'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary']]
ytrain = df_numeric[['Exited']]
   
# building the model and fitting the data
log_reg = sm.Logit(ytrain, Xtrain).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.453535
#          Iterations 6

# %%
Xtrain.head(3)
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
#
#    IsActiveMember  EstimatedSalary
# 0               1        101348.88
# 1               1        112542.58
# 2               0        113931.57

# %%
print(log_reg.summary())
# Out:
#                            Logit Regression Results
# ...
# Dep. Variable:                 Exited   No. Observations:                10000
# Model:                          Logit   Df Residuals:                     9992
# Method:                           MLE   Df Model:                            7
# Date:                Sun, 16 Jul 2023   Pseudo R-squ.:                  0.1028
# Time:                        18:37:33   Log-Likelihood:                -4535.3
# converged:                       True   LL-Null:                       -5054.9
# Covariance Type:            nonrobust   LLR p-value:                4.305e-220
# ...
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# CreditScore        -0.0039      0.000    -21.182      0.000      -0.004      -0.004
# Age                 0.0567      0.002     24.804      0.000       0.052       0.061
# ...

# %%
scaler = StandardScaler()

# %%
scaler.fit(Xtrain)
# Out:
# StandardScaler()

# %%
Xtrain_scaled =scaler.transform(Xtrain)

# %%
Xtrain_scaled_df =pd.DataFrame(Xtrain_scaled)

# %%
Xtrain_scaled_df.columns=['CreditScore', 'Age', 'Tenure', 'Balance',
       'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary']

# %%
log_reg_scaled = sm.Logit(ytrain, Xtrain_scaled_df).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.650253
#          Iterations 5

# %%
log_reg_scaled .summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                 Exited   No. Observations:                10000
# Model:                          Logit   Df Residuals:                     9992
# Method:                           MLE   Df Model:                            7
# Date:                Sun, 16 Jul 2023   Pseudo R-squ.:                 -0.2864
# Time:                        18:43:56   Log-Likelihood:                -6502.5
# converged:                       True   LL-Null:                       -5054.9
# Covariance Type:            nonrobust   LLR p-value:                     1.000
# ...
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# CreditScore        -0.0384      0.021     -1.835      0.066      -0.079       0.003
# ...
